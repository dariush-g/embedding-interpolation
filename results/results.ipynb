# %% [markdown]
# ### Recording the most probably outputs of "I love school because it's very..." as the embedding for the token "love" is interpolated to "hate"
# The vertical lines mark where the most probably outputs shifts from one token to another.

# %% [markdown]
# ![](love_hate_drift.png)

# %% [markdown]
# ### Recording the most probably outputs of "I like pizza, and I always get it with a lot of..." as the embedding for the token "pizza" is interpolated to "salad"

# %% [markdown]
# ![](pizza_salad_drift.png)
